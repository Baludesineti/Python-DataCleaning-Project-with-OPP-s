# %%
import pandas as pd
import numpy as np

# %%
emv = pd.read_csv("D:\Data Engineer books\CORE TOPICS\Data sets\EmployeeDataToClean.csv",encoding = "ISO-8859-1")

# %% [markdown]
# ### With out OPP's Data Cleaning

# %%
# sample Data Checking
data.head(4)
# Out:
#    EmployeeID  NationalIDNumber                 LoginID             Title  \
# 0           1          14417807    adventure-works\guy1    Gustavo Achong
# 1           2         253022876  adventure-works\kevin0    Catherine Abel
# 2           3         509647174                     NaN   Kim Abercrombie
# 3           4         112457891                     NaN  Humberto Acevedo
#
#     PhoneNumber         BirthDate MaritalStatus Gender          HireDate  \
# 0  9.257522e+09  21-02-1986 00:00             M      M  02-02-2013 00:00
# 1  9.235868e+09  12-03-1991 00:00             S      M  31-08-2013 00:00
# 2  9.416422e+09  21-09-1978 00:00             M      M  16-06-2014 00:00
# 3  8.800042e+09  01-11-1978 00:00             S      M  10-07-2014 00:00
#
#         Dept  Salary   Job Grade  CurrentFlag  \
# 0      Sales  2295.0       Admin           -1
# 1      Sales   962.0  Management           -1
# 2    Finance  4006.0       Admin           -1
# 3  Logistics  4547.0       Admin           -1
#
#                                   rowguid
# 0  {AAE1D04A-C237-4974-B4D5-935247737718}
# 1  {1B480240-95C0-410F-A717-EB29943C8886}
# 2  {9BBBFB2C-EFBB-4217-9AB7-F97689328841}
# 3  {59747955-87B8-443F-8ED4-F8AD3AFDF3A9}

# %%
# Volume Check
emv.shape
# Out:
# (50, 14)

# %%
# column volme chcking
emv.shape[1]
# Out:
# 14

# %%
# row valume check
emv.shape[0]
# Out:
# 50

# %%
# chcking Data types
emv.dtypes
# Out:
# EmployeeID            int64
# NationalIDNumber      int64
# LoginID              object
# Title                object
# PhoneNumber         float64
# BirthDate            object
# MaritalStatus        object
# Gender               object
# HireDate             object
# Dept                 object
# Salary              float64
# Job Grade            object
# CurrentFlag           int64
# rowguid              object
# dtype: object

# %%
# getting columns list
list(emv.columns)
# Out:
# ['EmployeeID',
#  'NationalIDNumber',
#  'LoginID',
#  'Title',
#  'PhoneNumber',
#  'BirthDate',
#  'MaritalStatus',
#  'Gender',
#  'HireDate',
#  'Dept',
#  'Salary',
#  'Job Grade',
#  'CurrentFlag',
#  'rowguid']

# %%
# getting the null values
emv.isna().sum()
# Out:
# EmployeeID           0
# NationalIDNumber     0
# LoginID             37
# Title                0
# PhoneNumber          7
# BirthDate            0
# MaritalStatus        0
# Gender               0
# HireDate             0
# Dept                 0
# Salary               6
# Job Grade            0
# CurrentFlag          0
# rowguid              0
# dtype: int64

# %%
# checking the null value persentage
(emv.isna().sum()/emv.shape[0])*100
# Out:
# EmployeeID           0.0
# NationalIDNumber     0.0
# LoginID             74.0
# Title                0.0
# PhoneNumber         14.0
# BirthDate            0.0
# MaritalStatus        0.0
# Gender               0.0
# HireDate             0.0
# Dept                 0.0
# Salary              12.0
# Job Grade            0.0
# CurrentFlag          0.0
# rowguid              0.0
# dtype: float64

# %%
# droping the columns
emv = emv.drop(["LoginID"],axis = 1)

# %%
# checking columns list
list(emv.columns)
# Out:
# ['EmployeeID',
#  'NationalIDNumber',
#  'Title',
#  'PhoneNumber',
#  'BirthDate',
#  'MaritalStatus',
#  'Gender',
#  'HireDate',
#  'Dept',
#  'Salary',
#  'Job Grade',
#  'CurrentFlag',
#  'rowguid']

# %%
# filling Missing values with mean in salary Column
emv["Salary"] = emv["Salary"].fillna(emv["Salary"].median())

# %%
# checking null values
emv.isna().sum()
# Out:
# EmployeeID          0
# NationalIDNumber    0
# Title               0
# PhoneNumber         7
# BirthDate           0
# MaritalStatus       0
# Gender              0
# HireDate            0
# Dept                0
# Salary              0
# Job Grade           0
# CurrentFlag         0
# rowguid             0
# dtype: int64

# %%
emv['PhoneNumber'] = emv['PhoneNumber'].fillna(0000000000)

# %%
try:
    emv['PhoneNumber'] = emv['PhoneNumber'].astype('int')
except Exception as e:
    print(e)

# %%
# Masking the phone number
def phno_masked(a):
    a = str(a)
    if a == '0':
        return "XXXXXXXXXX"
    result = a[0:3] + "XXXXX" + a[-2:]
    return result

# %%
emv['PhoneNumber'] = emv['PhoneNumber'].astype('object')

# %%
emv["PhoneNumber"] = emv['PhoneNumber'].apply(phno_masked)

# %%
emv["PhoneNumber"].head(10)
# Out:
# 0    925XXXXX51
# 1    923XXXXX60
# 2    941XXXXX59
# 3    880XXXXX25
# 4    XXXXXXXXXX
# 5    XXXXXXXXXX
# 6    XXXXXXXXXX
# 7    XXXXXXXXXX
# 8    918XXXXX76
# 9    941XXXXX79
# Name: PhoneNumber, dtype: object

# %%
# chaning the gender
try:
    emv["Gender"] = emv["Gender"].apply(lambda x: "Male" if x== "M" else "Female")
except Exception as e:
    print(e)

# %%
emv["Gender"].head(2)
# Out:
# 0    Male
# 1    Male
# Name: Gender, dtype: object

# %%
# changing the Marital Status
try:
    emv["MaritalStatus"] = emv["MaritalStatus"].apply(lambda x: "Married" if x== "M" else "Un-Married")
except Exception as e:
    print(e)

# %%
emv["MaritalStatus"].head(2)
# Out:
# 0       Married
# 1    Un-Married
# Name: MaritalStatus, dtype: object

# %%
# chaning the date data type
emv["BirthDate"] = pd.to_datetime(emv["BirthDate"],format = "%d-%m-%Y %H:%M")
emv["HireDate"] = pd.to_datetime(emv["HireDate"],format = "%d-%m-%Y %H:%M")

# %%
# Getting Unique values
emv["Job Grade"].unique()
# Out:
# array(['Admin', 'Management', 'Operations'], dtype=object)

# %%
# Getting Unique values count
emv["Job Grade"].nunique()
# Out:
# 3

# %% [markdown]
# ## With OPP's Data Cleaning

# %% [markdown]
# ### Writing the class

# %%
try:
    class DataCleaning:
        def __init__(self,data):
            self.data = data
   
        def volume_check(self):
            return self.data.shape
    
        def sample_data(self,n):
            return self.data.head(n)
    
        def row_count(self):
            print("The Number rows are given data:",self.data.shape[0])
    
        def coulmns_count(self):
            print("The Number columns are given data:",self.data.shape[1])
    
        def columns_list(self):
            return list(self.data.columns)
    
        def numaric_column_list(self):
            return list(self.data.select_dtypes(include= np.number).columns)
    
        def categroyical_columns_list(self):
            return list(self.data.select_dtypes(exclude=np.number).columns)
    
        def data_types(self):
            return self.data.dtypes
    
        def drop_duplicates(self):
            self.data = self.data.drop_duplicates()
    
        def drop_columns(self,col_name):
            self.data = self.data.drop(col_name,axis = 1)
    
        def drop_null(self,col_name):
            self.data = self.data.dropna(subset = [col_name])
    
        def missing_values(self):
            return self.data.isna().sum()
    
        def Getting_unique_count(self,col_name):
            return self.data[col_name].nunique()
    
        def getting_unique(self,col_name):
            return self.data[col_name].unique()
    
        def change_Gender(self,col_name):
            self.data[col_name] = self.data[col_name].apply(lambda x: "Male" if x== "M" else "Female")
    
        def change_Marrital_status(self,col_name):
            self.data[col_name] = self.data[col_name].apply(lambda x: "Married" if x== "M" else "Un-Married")
    
        def change_date_data_type(self,col_name):
            self.data[col_name] = pd.to_datetime(self.data[col_name],format = "%d-%m-%Y %H:%M")
    
        def Phone_masking(self,col_name):
            self.data[col_name] = self.data[col_name].fillna(0000000000).astype('int64').apply(lambda x:"XXXXXXXXXX" 
                                                                                               if x == 0 else x[0:3]+"XXXXX"+x[-2:])  
        
        def missing_values_presentage(self):
            return(self.data.isna().sum()/self.data.shape[0])*100
   
        def impute_missing_value_mean(self,col_name):
            self.data[col_name] = round(self.data[col_name].fillna(self.data[col_name].mean()),0).astype("int")
    
        def impute_missing_values_mode(self,col_name):
            self.data[col_name] = self.data[col_name].fillna(self.data[col_name].mode()[0])
    
        def impute_missing_values_median(self,col_name):
            self.data[col_name] = round(self.data[col_name].fillna(self.data[col_name].median()),0).astype("int")
    
        def impute_missing_values_other(self,col_name):
            self.data[col_name] = self.data[col_name].fillna("Not Avaialable")

except Exception as e:
    print(e)

# %%
# Loading agian same data set,
try:
    emv1 = pd.read_csv("D:\Data Engineer books\CORE TOPICS\Data sets\EmployeeDataToClean.csv",encoding = "ISO-8859-1")
except Exception as e:
    print(e)

# %%
try:
    df = DataCleaning(emv1)
except Exception as e:
    print(e)

# %%
# getting sample data with OPP's
df.sample_data(5)
# Out:
#    EmployeeID  NationalIDNumber                 LoginID             Title  \
# 0           1          14417807    adventure-works\guy1    Gustavo Achong
# 1           2         253022876  adventure-works\kevin0    Catherine Abel
# 2           3         509647174                     NaN   Kim Abercrombie
# 3           4         112457891                     NaN  Humberto Acevedo
# 4           5         480168528                     NaN    Pilar Ackerman
#
#     PhoneNumber         BirthDate MaritalStatus Gender          HireDate  \
# 0  9.257522e+09  21-02-1986 00:00             M      M  02-02-2013 00:00
# 1  9.235868e+09  12-03-1991 00:00             S      M  31-08-2013 00:00
# 2  9.416422e+09  21-09-1978 00:00             M      M  16-06-2014 00:00
# 3  8.800042e+09  01-11-1978 00:00             S      M  10-07-2014 00:00
# 4           NaN  07-06-1963 00:00             M      M  16-07-2014 00:00
#
#              Dept  Salary   Job Grade  CurrentFlag  \
# 0           Sales  2295.0       Admin           -1
# 1           Sales   962.0  Management           -1
# 2         Finance  4006.0       Admin           -1
# 3       Logistics  4547.0       Admin           -1
# 4  Human Resource  1932.0       Admin           -1
#
#                                   rowguid
# 0  {AAE1D04A-C237-4974-B4D5-935247737718}
# 1  {1B480240-95C0-410F-A717-EB29943C8886}
# 2  {9BBBFB2C-EFBB-4217-9AB7-F97689328841}
# 3  {59747955-87B8-443F-8ED4-F8AD3AFDF3A9}
# 4  {1D955171-E773-4FAD-8382-40FD898D5D4D}

# %%
# getting the data types with OPP's
df.data_types()
# Out:
# EmployeeID            int64
# NationalIDNumber      int64
# LoginID              object
# Title                object
# PhoneNumber         float64
# BirthDate            object
# MaritalStatus        object
# Gender               object
# HireDate             object
# Dept                 object
# Salary              float64
# Job Grade            object
# CurrentFlag           int64
# rowguid              object
# dtype: object

# %%
# getting the volume with OPP's
df.volume_check()
# Out:
# (50, 14)

# %%
# getting the columns count with OPP's
df.coulmns_count()
# Out:
# The Number columns are given data: 14

# %%
# getting the rows count with OPP's
df.row_count()
# Out:
# The Number rows are given data: 50

# %%
# getting columns list with OPP's
df.columns_list()
# Out:
# ['EmployeeID',
#  'NationalIDNumber',
#  'LoginID',
#  'Title',
#  'PhoneNumber',
#  'BirthDate',
#  'MaritalStatus',
#  'Gender',
#  'HireDate',
#  'Dept',
#  'Salary',
#  'Job Grade',
#  'CurrentFlag',
#  'rowguid']

# %%
# getting the missing values count with OPP's
df.missing_values()
# Out:
# EmployeeID           0
# NationalIDNumber     0
# LoginID             37
# Title                0
# PhoneNumber          7
# BirthDate            0
# MaritalStatus        0
# Gender               0
# HireDate             0
# Dept                 0
# Salary               6
# Job Grade            0
# CurrentFlag          0
# rowguid              0
# dtype: int64

# %%
# getting the missing values Persentage with OPP's
df.missing_values_presentage()
# Out:
# EmployeeID           0.0
# NationalIDNumber     0.0
# LoginID             74.0
# Title                0.0
# PhoneNumber         14.0
# BirthDate            0.0
# MaritalStatus        0.0
# Gender               0.0
# HireDate             0.0
# Dept                 0.0
# Salary              12.0
# Job Grade            0.0
# CurrentFlag          0.0
# rowguid              0.0
# dtype: float64

# %%
# drop the columns with OPP's
df.drop_columns("LoginID")

# %%
df.columns_list()
# Out:
# ['EmployeeID',
#  'NationalIDNumber',
#  'Title',
#  'PhoneNumber',
#  'BirthDate',
#  'MaritalStatus',
#  'Gender',
#  'HireDate',
#  'Dept',
#  'Salary',
#  'Job Grade',
#  'CurrentFlag',
#  'rowguid']

# %%
# filling salary with OPP's
df.impute_missing_values_median("Salary")

# %%
# Changning the Birthdate data type
df.change_date_data_type("BirthDate")

# %%
# Changning the Hiredate data type
df.change_date_data_type("HireDate")

# %% [markdown]
# #### This OPP's DataCleaning Class we can apply any data set not for a one data set

# %% [markdown]
# # Inheritance

# %% [markdown]
# ### 1. Take a copy to complete the class and add ur method (not recommended)
# ### 2. We can't modify the existing class (Exis,t Clas,s possibly that some team, some team member would have implemented) (not recommended)
# ### 3. We can use existing classes,s and u are allowed to use your own code (Recommended) ----> Inheritance

# %%
def AdvDataCleaning(DataCleaning):
    def missing_values_fill_zero(self,col_name):
        self.data = self.data[col_name].fillna(0).astype('int')

# %%
df1 = AdvDataCleaning(df)
